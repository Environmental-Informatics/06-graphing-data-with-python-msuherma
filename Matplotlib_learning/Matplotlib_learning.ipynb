# %%
import matplotlib.pyplot as plt

x = [1,2,3]
y = [5,7,4]

x2 = [1,2,3]
y2 = [10,14, 12]

plt.plot(x,y, label = '1st Line')
plt.plot(x2,y2, label = '2nd Line')
plt.xlabel('plot Number')
plt.ylabel('important var')
plt.title('Learn_plotting \nCheck it out')
plt.legend()

plt.show()
